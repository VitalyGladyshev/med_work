# %% [markdown]
# <a href="https://colab.research.google.com/github/VitalyGladyshev/med_work/blob/main/DSM_HW2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ДЗ 2 Гладышев В.В.
# ## Введение в анализ данных в медицине
# ## Урок 2. Источники медицинских данных

# %% [markdown]
# Датасет по хронической обструктивной болезни легких и сердечно-сосудистому риску

# %% [markdown]
# # Разведочный анализ EDA - степень ХОБЛ
#
# Проанализированы раздельно группы 2, 3 и совместно 2-3
#
# Данные предварительно очищены, разбиты на группы в отдельных csv файлах

# %% [markdown]
# ## Группа 3

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

# %%
data_3 = pd.read_csv("ikm_start_3.csv")
data_3.head()
# Out:
#    эндотели   ЧСС  E_A  СрДЛА  ТС_ПЖ    ПП  IVRT  E_A_ЛЖ    ЛП  ТМЖП  ...  \
# 0     1.489  68.0  0.5   24.9    0.3  38.0  70.0     0.9  38.0  11.0  ...
# 1     1.315  67.0  0.6   18.4    0.4  38.0  71.0     0.8  37.0   9.0  ...
# 2     2.874  68.0  0.3   18.7    0.3  37.0  72.0     0.9  36.0   8.0  ...
# 3    16.182  68.0  0.3   24.8    0.7  36.0  73.0     0.9  35.0   9.0  ...
# 4     9.134  69.0  0.5   18.4    0.4  36.0  83.0     0.8  34.0  11.0  ...
#
#         S   Imax    Imax_S  стп_ХОБЛ  офв1  эндотелин   хс    ик  пол1  \
# 0  4100.0  755.0  0.184146       3.0  27.0      4.000  5.4  20.0   1.0
# 1  2437.0  573.0  0.235125       3.0  30.0      4.000  5.5  27.0   0.0
# 2  1765.0  356.0  0.201700       1.0  85.0      2.874  5.6  10.0   1.0
# 3  1765.0  543.0  0.307649       2.0  75.0     16.182  5.7  15.0   1.0
# 4   657.0  122.0  0.185693       1.0  -1.0      9.134  5.8  -1.0   0.0
#
#    возраст
# 0     48.0
# 1     59.0
# 2     40.0
# 3     54.0
# 4     45.0
#
# ...

# %%
data_3.describe()
# Out:
#         эндотели        ЧСС        E_A      СрДЛА      ТС_ПЖ         ПП  \
# count  31.000000  31.000000  31.000000  31.000000  31.000000  31.000000
# mean    1.168613  71.419355   0.606452  19.948387   0.403226  37.741935
# std     3.772435   9.611709   0.169185   3.281755   0.119677   1.590969
# min    -1.000000  58.000000   0.300000  16.200000   0.300000  35.000000
# 25%    -1.000000  65.500000   0.500000  17.400000   0.300000  37.000000
# 50%    -1.000000  68.000000   0.600000  18.700000   0.400000  38.000000
# 75%     1.438500  81.500000   0.800000  24.150000   0.450000  38.500000
# max    16.182000  91.000000   0.800000  24.900000   0.700000  41.000000
#
#              IVRT     E_A_ЛЖ         ЛП       ТМЖП  ...            S  \
# count   31.000000  31.000000  31.000000  31.000000  ...    31.000000
# mean    81.322581   0.841935  36.903226   9.612903  ...  1624.419355
# std      6.347635   0.187571   1.955417   1.054433  ...  1009.541175
# ...

# %%
data_3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119 entries, 0 to 118
# Data columns (total 34 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   эндотели   31 non-null     float64
#  1   ЧСС        31 non-null     float64
#  2   E_A        31 non-null     float64
#  3   СрДЛА      31 non-null     float64
#  4   ТС_ПЖ      31 non-null     float64
#  5   ПП         31 non-null     float64
#  6   IVRT       31 non-null     float64
#  7   E_A_ЛЖ     31 non-null     float64
#  8   ЛП         31 non-null     float64
#  9   ТМЖП       31 non-null     float64
#  10  ТЗС_ЛЖ     31 non-null     float64
#  11  ФВ         31 non-null     float64
#  12  УО         31 non-null     float64
#  13  КДО_ЛЖ     31 non-null     float64
#  14  КСО_ЛЖ     31 non-null     float64
#  15  КДР_ЛЖ     31 non-null     float64
#  16  КСР_ЛЖ     31 non-null     float64
#  17  no2        31 non-null     float64
#  18  no3        31 non-null     float64
# ...

# %%
sns.heatmap(data_3.corr('pearson'), annot=False)
# Out:
# <Axes: >

# %%
sns.heatmap(data_3.corr('kendall'), annot=False)
# Out:
# <Axes: >

# %%
sns.heatmap(data_3.corr('spearman'), annot=False)
# Out:
# <Axes: >

# %%
sns.heatmap(data_3[[
'ЧСС',
'E_A',
'СрДЛА',
'ТС_ПЖ',
'ПП',
'IVRT',
'E_A_ЛЖ',

'стп_ХОБЛ'
                    ]].corr(), annot=True)
# Out:
# <Axes: >

# %%
sns.heatmap(data_3[[
'ЛП',
'ТМЖП',
'ТЗС_ЛЖ',
'ФВ',
'УО',
'КДО_ЛЖ',
'КСО_ЛЖ',
'КДР_ЛЖ',
'КСР_ЛЖ',

'стп_ХОБЛ'
                    ]].corr(), annot=True)
# Out:
# <Axes: >

# %%
sns.heatmap(data_3[[
'no2',
'no3',
'эзвд',
'ДК',
'ТК',
'ОШ',
'ОШ_ДК_ТК',
'S',

'стп_ХОБЛ'
                    ]].corr(), annot=True)
# Out:
# <Axes: >

# %%
sns.heatmap(data_3[[
'Imax',
'Imax_S',
'офв1',
'эндотели',
'эндотелин',
'хс',
'ик',
'пол1',
'возраст',

'стп_ХОБЛ'
                    ]].corr(), annot=True)
# Out:
# <Axes: >

# %%
sns.heatmap(data_3[[
'эндотели',
'СрДЛА',
'IVRT',
'КДР_ЛЖ',
'ДК',
'ОШ',
'ОШ_ДК_ТК',
'ик',
'возраст',

'стп_ХОБЛ'
        ]].corr('pearson'), annot=True)
# Out:
# <Axes: >

# %%
sns.heatmap(data_3[[
'эндотели',
'СрДЛА',
'IVRT',
'КДР_ЛЖ',
'ДК',
'ОШ',
'ОШ_ДК_ТК',
'ик',
'возраст',

'стп_ХОБЛ'
        ]].corr('kendall'), annot=True)
# Out:
# <Axes: >

# %%
sns.heatmap(data_3[[
'эндотели',
'СрДЛА',
'IVRT',
'КДР_ЛЖ',
'ДК',
'ОШ',
'ОШ_ДК_ТК',
'ик',
'возраст',

'стп_ХОБЛ'
        ]].corr('spearman'), annot=True)
# Out:
# <Axes: >

# %%
sns.set_style("ticks")
sns.pairplot(data_3[[
'ЧСС',
'E_A',
'СрДЛА',
'ТС_ПЖ',
'ПП',
'IVRT',
'E_A_ЛЖ',

'стп_ХОБЛ'
                    ]], kind="reg")
plt.show()

# %%
sns.set_style("ticks")
sns.pairplot(data_3[[
'ЛП',
'ТМЖП',
'ТЗС_ЛЖ',
'ФВ',
'УО',
'КДО_ЛЖ',
'КСО_ЛЖ',
'КДР_ЛЖ',
'КСР_ЛЖ',

'стп_ХОБЛ'
                    ]], kind="reg")
plt.show()

# %%
sns.set_style("ticks")
sns.pairplot(data_3[[
'no2',
'no3',
'эзвд',
'ДК',
'ТК',
'ОШ',
'ОШ_ДК_ТК',
'S',

'стп_ХОБЛ'
                    ]], kind="reg")
plt.show()

# %%
sns.set_style("ticks")
sns.pairplot(data_3[[
'Imax',
'Imax_S',
'офв1',
'эндотели',
'эндотелин',
'хс',
'ик',
'пол1',
'возраст',

'стп_ХОБЛ'
                    ]], kind="reg")
plt.show()
